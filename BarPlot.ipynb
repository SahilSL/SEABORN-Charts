# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('')
sns.barplot(x="",y="",data=df)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=sns.load_dataset('')
#       2 sns.barplot(x="",y="",data=df)
#       3 plt.show
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: '' is not one of the example datasets.

# %%
var=sns.load_dataset('penguins')
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x=var.island,y=var.bill_length_mm, data=var)
# Out:
# <Axes: xlabel='island', ylabel='bill_length_mm'>

# %%
sns.barplot(x=var.island,y=var.bill_length_mm, data=var)
plt.show()

# %%
sns.barplot(x='island',y='bill_length_mm', data=var)
plt.show()

# %%
sns.barplot(x='island',y='bill_length_mm', data=var, hue='sex')
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var, hue='sex', order=order1)
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var, hue='sex', hue_order=["Female","Male"], order=order1)
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='bill_depth_mm',y='bill_length_mm', data=var, orient="h")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='bill_depth_mm',y='bill_length_mm', data=var, orient="v")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var, color="g")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var,hue="sex", palette="icefire")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var,hue="sex", palette="icefire", alpha=0.5)
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x='island',y='bill_length_mm', data=var,hue="sex", palette="icefire", alpha=0.5)
plt.show()
plt.savefig("snsbarplot.png")
