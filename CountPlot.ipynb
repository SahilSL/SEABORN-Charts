# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset("")
sns.countplot(x='', data=df)
plt.show()

# %%
Countplot plots the count of the numberss of records by category

barplot plots a value for each category

# %%
var = sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='total_bill', data=var)
plt.show()

# %%
sns.countplot(x='sex', data=var)
plt.show()

# %%
sns.countplot(x='day', data=var)
plt.show()

# %%
sns.countplot(x='sex', data=var, hue="smoker")
plt.show()

# %%
sns.countplot(y='sex', data=var, hue="smoker")
plt.show()

# %%
sns.countplot(y='sex', data=var, hue="smoker", palette="ocean_r")
plt.show()

# %%
sns.countplot(y='sex', data=var, hue="smoker", color="g")
plt.show()
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_25180\1530093492.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.countplot(y='sex', data=var, hue="smoker", color="g")
